# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D  
import random
from pandas import read_csv


series=read_csv("solar-class-data3D.txt", sep="\t", header=None,parse_dates=True)
series=np.array(series.values)

x=range(0,60,1)
y=[0.25,0.15,0.075]

print(series, series.shape)
print(series[0])
print(series[59])

print(x)
print(y)

def getXY1(x0,y0,ix):
    if(y0==0.075):
        return series[x0][4+ix]
    if(y0==0.15):
        return series[x0][9+ix]
    if(y0==0.25):
        return series[x0][14+ix]
    return None




fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

zs= [getXY1(xi,0) for xi in x]
zs=np.array(zs)


# plot lines

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X[0], Z[0], label = "alpha=0.075", linestyle="-")
ax.plot(X[0], Z[1], label = "alpha=0.15", linestyle=":")
ax.plot(X[0], Z[2], label = "alpha=0.25", linestyle="-.")
plt.xlabel('epoch', fontsize=10)
plt.ylabel('accuracy real samples', fontsize=10)

ax.legend()
fig.show()
# Out:
# [[ 1.         0.075     17.748182  ...        nan        nan        nan]
#  [ 2.         0.075     11.423644  ...        nan        nan        nan]
#  [ 3.         0.075      9.89196   ...        nan        nan        nan]
#  ...
#  [58.         0.075      6.0250993 ...        nan        nan        nan]
#  [59.         0.075      6.5828867 ...        nan        nan        nan]
#  [60.         0.075      6.8406196 ...        nan        nan        nan]] (60, 32)
# [ 1.          0.075      17.748182    0.07313491  0.76298891  0.75277291
#   0.15       26.618065    0.10968504  0.74518389  1.          0.25
#  21.463575    0.08844493  0.77291302  1.                 nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan         nan]
# [6.00000000e+01 7.50000000e-02 6.84061960e+00 2.81881340e-02
#  4.88616462e-01 1.00000000e+00 1.50000000e-01 1.40341240e+01
# ...

# %%
# plot lines

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X[0], Z[0], label = "alpha=0.075", linestyle="-")
ax.plot(X[0], Z[1], label = "alpha=0.15", linestyle=":")
ax.plot(X[0], Z[2], label = "alpha=0.25", linestyle="-.")
plt.xlabel('epoch', fontsize=10)
plt.ylabel('accuracy real samples', fontsize=10)

ax.legend()
fig.show()
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_17484\1556676411.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_17484\2542076249.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Z[0]
# Out:
# array([0.08844493, 0.08081798, 0.04805205, 0.05612416, 0.04869695,
#        0.05623886, 0.036802  , 0.05577187, 0.04343175, 0.05983524,
#        0.05126041, 0.07078186, 0.04299623, 0.03397371, 0.04135414,
#        0.05446705, 0.03718829, 0.03982309, 0.03437933, 0.03624551,
#        0.04109265, 0.05068135, 0.05107216, 0.03975628, 0.07001685,
#        0.03132577, 0.04434705, 0.04523942, 0.05149199, 0.04047142,
#        0.04085955, 0.04194601, 0.04340266, 0.04843557, 0.03576747,
#        0.04614843, 0.03778041, 0.05744371, 0.04280709, 0.03541548,
#        0.0334742 , 0.04339102, 0.04564642, 0.03312588, 0.03795197,
#        0.05143489, 0.04638544, 0.03558228, 0.04617626, 0.04228715,
#        0.03720428, 0.03553532, 0.05040587, 0.0440098 , 0.03057535,
#        0.03197116, 0.04095452, 0.07098535, 0.03826126, 0.0292743 ])
